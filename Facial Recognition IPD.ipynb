# %%
pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 61.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=fe8a4098d73ab9724f0a9a3ad54cbb6a376869665320b8247ac18ab34903d667
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Read more at: https://viso.ai/computer-vision/deepface/
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
img1 = cv2.imread("/content/img1.jpg")
img2 = cv2.imread("/content/img2.jpg")

# %%
cv2_imshow(img1)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384 at 0x7FC9755A66A0>
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FC9755052B0>

# %%
models = ["VGG-Face", "Facenet", "OpenFace", "DeepFace"]

# %%
verification = []
for i in models:
  verification.append(DeepFace.verify(img1_path = "/content/img1.jpg", img2_path = "/content/img2.jpg",model_name = i))
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:05<00:00, 113MB/s]
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: /root/.deepface/weights/facenet_weights.h5
# facenet_weights.h5 will be downloaded...
# 100%|██████████| 92.2M/92.2M [00:00<00:00, 178MB/s]
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5
# To: /root/.deepface/weights/openface_weights.h5
# openface_weights.h5 will be downloaded...
# 100%|██████████| 15.3M/15.3M [00:00<00:00, 203MB/s]
# Downloading...
# From: https://github.com/swghosh/DeepFace/releases/download/weights-vggface2-2d-aligned/VGGFace2_DeepFace_weights_val-0.9034.h5.zip
# To: /root/.deepface/weights/VGGFace2_DeepFace_weights_val-0.9034.h5.zip
# ...

# %%
verification
# Out:
# [{'verified': True,
#   'distance': 0.11926144802854322,
#   'threshold': 0.4,
#   'model': 'VGG-Face',
#   'detector_backend': 'opencv',
#   'similarity_metric': 'cosine',
#   'facial_areas': {'img1': {'x': 117, 'y': 82, 'w': 172, 'h': 172},
#    'img2': {'x': 350, 'y': 163, 'w': 315, 'h': 315}},
#   'time': 12.97},
#  {'verified': True,
#   'distance': 0.13481874184951803,
#   'threshold': 0.4,
#   'model': 'Facenet',
#   'detector_backend': 'opencv',
#   'similarity_metric': 'cosine',
#   'facial_areas': {'img1': {'x': 117, 'y': 82, 'w': 172, 'h': 172},
#    'img2': {'x': 350, 'y': 163, 'w': 315, 'h': 315}},
#   'time': 8.63},
#  {'verified': False,
#   'distance': 0.1147723914150297,
#   'threshold': 0.1,
#   'model': 'OpenFace',
#   'detector_backend': 'opencv',
#   'similarity_metric': 'cosine',
#   'facial_areas': {'img1': {'x': 117, 'y': 82, 'w': 172, 'h': 172},
#    'img2': {'x': 350, 'y': 163, 'w': 315, 'h': 315}},
#   'time': 3.51},
#  {'verified': False,
# ...
